# %% [markdown]
# Visualizing data effectively is crucial for making informed decisions, and this guide is a perfect reference for selecting the right chart based on your objective. Whether you're presenting marketing metrics, analyzing survey data, or identifying business trends — the right visual can make all the difference!
#
# 🔹 Bar Chart – Compare categories (e.g., product sales)
# 🔹 Line Chart – Show trends over time (e.g., web traffic growth)
# 🔹 Pie/Donut Chart – Highlight proportions (e.g., budget breakdown)
# 🔹 Scatter Plot – Reveal relationships (e.g., spend vs. ROI)
# 🔹 Histogram – Display data distribution (e.g., age demographics)
# 🔹 Radar Chart – Compare across dimensions (e.g., performance metrics)
# 🔹 Map – Visualize geospatial data (e.g., regional sales)
# 🔹 Heatmap – Show data patterns (e.g., customer behavior)
# 🔹 Bubble Chart – Represent 3D data (e.g., revenue, cost, profit)

# %%
plt.title("Customized Title", fontdict={
    'fontsize': 16,
    'fontweight': 'bold',
    'fontname': 'Arial'
})

# %% [markdown]
# plt.title("Customized Title", fontdict={
#     'fontsize': 16,
#     'fontweight': 'bold',
#     'fontname': 'Arial'
# })
# x = [1, 2, 3, 4, 5]
# y1 = [2, 3, 5, 7, 11]
# y2 = [1, 4, 6, 8, 10]
# plt.plot(x, y1, label='Line 1', color='blue')  # First line
# plt.plot(x, y2, label='Line 2', color='green') # Second line
# plt.title("Two Line Charts with Legend")
# plt.xlabel("X-axis")
# plt.ylabel("Y-axis")
# plt.legend()  # Show legend
# plt.grid(True)
# plt.show()
# plt.legend(loc='upper left')  # Position
# 'upper right' (default)
# 'upper left'
# 'lower left'
# 'lower right'
# 'center', 'best'
# plt.grid(
#     True,
#     which='both',           # 'major', 'minor', or 'both'
#     linestyle='--',         # Line style: '-', '--', '-.', ':'
#     linewidth=0.8,          # Thickness of grid lines
#     color='gray',           # Grid line color
#     alpha=0.7               # Transparency (0 to 1)
# )
# import matplotlib.image as mpimg
# # Load background image
# img = mpimg.imread('your_image.png')  # PNG, JPG, etc.
# # Show the image (as background)
# ax.imshow(img, extent=[0, 10, 0, 10], aspect='auto')  # Adjust extent to fit
# fig, ax = plt.subplots()
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# #Load background image
# img = mpimg.imread('your_image.png')  # PNG, JPG, etc.
# fig, ax = plt.subplots()
# #Show the image (as background)
# ax.imshow(img, extent=[0, 10, 0, 10], aspect='auto')  # Adjust extent to fit
# #
# Plot data on top
# x = [1, 2, 3, 4, 5]
# y = [2, 4, 6, 8, 10]
# ax.plot(x, y, color='blue', linewidth=2, label='Line on I
# ax.plot(x, y, color='blue', linewidth=2, label='Line on Image')
# # Other plot settings
# ax.set_xlim(0, 10)
# ax.set_ylim(0, 10)
# ax.legend()
# ax.set_title("Plot with Image Background")
# plt.show()

# %%
import matplotlib.pyplot as plt

# %%
categories=['a','b','c']
values=[10,20,30]
plt.bar(categories,values)
plt.title('barchart')
plt.xlabel('categories')
plt.ylabel('values')
plt.show()

# %%
data = [22, 25, 22, 30, 28, 25, 30, 29, 27, 30]
plt.hist(data,bins=3)
plt.title('histograph',color='#ff5733')
plt.xlabel('data')
plt.ylabel('y')

plt.savefig('histheloo.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#Load background image
img = mpimg.imread('histheloo.jpg')  # PNG, JPG, etc.
fig, ax = plt.subplots()
#Show the image (as background)
ax.imshow(img, extent=[0, 10, 0, 10], aspect='auto')  # Adjust extent to fit
#Plot data on top
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
ax.plot(x, y, color='blue', linewidth=2, label='Line on Image')
# Other plot settings
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.legend()
ax.set_title("Plot with Image Background")
plt.show()

# %% [markdown]
# Matplotlib
# Low-level data visualization library.
# Offers complete control over plot elements (axes, labels, ticks, etc.).
# Syntax can be more complex and verbose.
# Basic styling by default.
# Suitable for custom, detailed plots.
# Works with NumPy arrays, lists, and Pandas.
# Widely used in the Python ecosystem.

# %% [markdown]
# Seaborn
# High-level API built on top of Matplotlib.
# Provides beautiful default themes and color palettes.
# Simplifies creation of complex plots like violin plots, swarm plots, etc.
# Works directly with Pandas DataFrames.
# Supports statistical visualizations with minimal code.
# Less customizable than Matplotlib, but faster for common plots.
# Great for quick and informative EDA (Exploratory Data Analysis)

# %% [markdown]
# hist==> used to show the distribution of a single variable.
# bar==> used for comparing categories based on numerical values.
# scatter==> show the relationship b/w 2 numeric variables.
# line plot==>to show the trend or change in data over time.
# pie chart==> represents a part of whole

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data
df = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
    'Sales': [250, 300, 400, 350, 500]
})

# %%
df
# Out:
#   Month  Sales
# 0   Jan    250
# 1   Feb    300
# 2   Mar    400
# 3   Apr    350
# 4   May    500

# %%
sns.lineplot(x='Month',y='Sales',data=df)
plt.title('line plot using sns')
# Out:
# Text(0.5, 1.0, 'line plot using sns')

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title('total bill vs tips')
# Out:
# Text(0.5, 1.0, 'total bill vs tips')

# %%
sns.barplot(x='day',y='tip',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.histplot(data=tips,x='total_bill',bins=5,kde=True) #bins: represents the range of value
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Data
labels = ['A', 'B', 'C', 'D']
sizes = [25, 35, 20, 20]

# %%
plt.pie(sizes,labels=labels,autopct='%1.1f%%',startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1437d7374d0>,
# ...
#  [Text(-1.0958141611915575, -0.09587139371075998, 'A'),
#   Text(0.42980436531207517, -1.012555286173888, 'B'),
#   Text(0.9328527021418345, 0.5829115165328939, 'C'),
#   Text(-0.266115004275379, 1.0673250697418828, 'D')],
#  [Text(-0.5977168151953949, -0.05229348747859634, '25.0%'),
#   Text(0.23443874471567733, -0.5523028833675753, '35.0%'),
#   Text(0.5088287466228187, 0.3179517362906693, '20.0%'),
#   Text(-0.14515363869566125, 0.5821773107682997, '20.0%')])

# %%
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1437d777750>,
# ...
#  [Text(0.777817442305461, 0.7778174763049434, 'A'),
#   Text(-0.9801072434824519, 0.49938941846341695, 'B'),
#   Text(-0.33991831634615544, -1.046162290570825, 'C'),
#   Text(0.8899186414035474, -0.6465638496563697, 'D')],
#  [Text(0.4242640594393423, 0.4242640779845145, '25.0%'),
#   Text(-0.5346039509904282, 0.2723942282527728, '35.0%'),
#   Text(-0.1854099907342666, -0.5706339766749954, '20.0%'),
#   Text(0.4854101680382985, -0.3526711907216562, '20.0%')])

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
# Plot
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart Example')
plt.axis('equal')  # Equal aspect ratio ensures pie is a circle
plt.show()

# %% [markdown]
# python
# 1. Data types
# 2. Data Structures in Python
# 3.Conditional Statements
# 4.Control Statements
# 5.file handling
# 6.exception Handling
# 7.Functions
# 8. Lambda Functions
# 9. List Comprehension
# 10.Numpy
# 11. Pandas
# 12.Matplotlib
# 14. Seaborn
# Definition, Synatax, Example
