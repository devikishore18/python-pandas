# %%
#pandas lib for data manipulation and data analysis
import pandas as pd

# %% [markdown]
# 1.series -->  1d labelled array, any datatype
# 2.dataframes --->2d labelled data structure
# 3.panels

# %%
data=[1,2,3,4,5]
s1=pd.Series(data)
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
#customising the index value
s2=pd.Series(data,index=['a','b','c','d','e'])
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2['a']
# Out:
# np.int64(1)

# %%
s2['b']
# Out:
# np.int64(2)

# %%
dict={'a':1,'b':2,'c':3,'d':4,'e':5}
dict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
s3=pd.Series(dict)
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#scalar values---every index have same values
s4=pd.Series(5,index=['x','y','z'])
s4
# Out:
# x    5
# y    5
# z    5
# dtype: int64

# %%
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s3+10
# Out:
# a    11
# b    12
# c    13
# d    14
# e    15
# dtype: int64

# %%
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s3*3
# Out:
# a     3
# b     6
# c     9
# d    12
# e    15
# dtype: int64

# %%
#dataframe
data = {
 'Name': ['Alice', 'Bob', 'Charlie'],
 'Age': [25, 30, 35],
 'City': ['New York', 'Mumbai', 'London']
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'City': ['New York', 'Mumbai', 'London']}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    Mumbai
# 2  Charlie   35    London

# %%
data1=pd.read_csv('default of credit card clients - Data.csv')
data1
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df1=pd.DataFrame(data1)
df1
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
#exploratory data analysis EDA
#It helps you understand the structure, patterns, anomalies, and relationships within a dataset.
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    Mumbai
# 2  Charlie   35    London

# %%
df1.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df1.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %%
df1.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df1.tail(10)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29990  29991     140000    1          2         1   41      0      0      0
# 29991  29992     210000    1          2         1   34      3      2      2
# 29992  29993      10000    1          3         1   43      0      0      0
# 29993  29994     100000    1          1         2   38      0     -1     -1
# 29994  29995      80000    1          2         2   34      2      2      2
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df1.shape
# Out:
# (30000, 25)

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df1.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df1.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %% [markdown]
# df.head() # First 5 rows
# df.tail() # Last 5 rows
# df.shape # Rows and columns
# df.columns # Column names
# df.info() # Data types and nulls
# df.describe() # Statistical summary

# %%
import numpy as np
import pandas as pd

# %%
data = {
 'Math': [90, 85, np.nan, 88],
 'Science': [np.nan, 78, 85, 82],
 'English': [75, 80, 78, np.nan]
}
data
# Out:
# {'Math': [90, 85, nan, 88],
#  'Science': [nan, 78, 85, 82],
#  'English': [75, 80, 78, nan]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    Math  Science  English
# 0  90.0      NaN     75.0
# 1  85.0     78.0     80.0
# 2   NaN     85.0     78.0
# 3  88.0     82.0      NaN

# %%
df.index=['stu1','stu2','stu3','stu4']
df
# Out:
#       Math  Science  English
# stu1  90.0      NaN     75.0
# stu2  85.0     78.0     80.0
# stu3   NaN     85.0     78.0
# stu4  88.0     82.0      NaN

# %%
df.isna().sum()
# Out:
# Math       1
# Science    1
# English    1
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)

# %%
df
# Out:
#            Math    Science    English
# stu1  90.000000  81.666667  75.000000
# stu2  85.000000  78.000000  80.000000
# stu3  87.666667  85.000000  78.000000
# stu4  88.000000  82.000000  77.666667

# %%
df.isna().sum()
# Out:
# Math       0
# Science    0
# English    0
# dtype: int64

# %%
data = {
 'Name': ['Alice', 'Bob', 'Alice', 'Charlie'],
 'Age': [25, 30, 25, 35]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2    Alice   25
# 3  Charlie   35

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35

# %%
df.drop_duplicates(subset=['Name'],keep='last')
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# df.fillna(df.mean(numeric_only=True), inplace=True)
# df.drop_duplicates(inplace=True)

# %% [markdown]
# df.dtypes # Check column types
# df['col'] = df['col'].astype('int') # Convert type
# Syntax
# df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)
# df.replace({'SEX': {1 : 'Male', 2 : 'Female'}}, inplace=True)
# df.replace({'EDUCATION' : {1 : 'Graduate School', 2 : 'University', 3 : 'High School', 4 : 'Others'}}, inplace=True)
# df.replace({'MARRIAGE' : {1 : 'Married', 2 : 'Single', 3 : 'Others'}}, inplace = True)
# df.replace({'default payment next month' : {1 : 'Yes', 0 : 'No'}}, inplace = True)
# target_value_count = df['default payment next month'].value_counts() # Counting y variable counts
#
# print(target_value_count)

# %% [markdown]
# regression&classification
# instances 10k+
# features 10 to 15 +

# %%
df
# Out:
#            Math    Science    English
# stu1  90.000000  81.666667  75.000000
# stu2  85.000000  78.000000  80.000000
# stu3  87.666667  85.000000  78.000000
# stu4  88.000000  82.000000  77.666667

# %%
df.loc['stu1']
# Out:
# Math       90.000000
# Science    81.666667
# English    75.000000
# Name: stu1, dtype: float64

# %%
df.iloc[-1]
# Out:
# Math       88.000000
# Science    82.000000
# English    77.666667
# Name: stu4, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, stu1 to stu4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     4 non-null      float64
#  1   Science  4 non-null      float64
#  2   English  4 non-null      float64
# dtypes: float64(3)
# memory usage: 300.0+ bytes

# %%
df.dtypes
# Out:
# Math       float64
# Science    float64
# English    float64
# dtype: object

# %%
df['Math']=df['Math'].astype('int')
df.dtypes
# Out:
# Math         int64
# Science    float64
# English    float64
# dtype: object

# %%
df['Math'].to_frame()
# Out:
#       Math
# stu1    90
# stu2    85
# stu3    87
# stu4    88

# %%
df[['Math','Science']]
# Out:
#       Math    Science
# stu1    90  81.666667
# stu2    85  78.000000
# stu3    87  85.000000
# stu4    88  82.000000

# %%
df[::-1]
# Out:
#       Math    Science    English
# stu4    88  82.000000  77.666667
# stu3    87  85.000000  78.000000
# stu2    85  78.000000  80.000000
# stu1    90  81.666667  75.000000

# %%
df.isna()
# Out:
#        Math  Science  English
# stu1  False    False    False
# stu2  False    False    False
# stu3  False    False    False
# stu4  False    False    False

# %%
pd.isnull(None)
# Out:
# True

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %%
pd.isnull((pd.Series([1,np.nan,7])))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
pd.notnull((pd.Series([1,np.nan,7])))
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool
